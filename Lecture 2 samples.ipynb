# %%
from scipy.integrate import odeint
import numpy as np

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6540910f-4afe-4964-9052-e06bce3e645c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # A resistor-capacitor circuit
#
# ![A resistor-capacitor circuit](RCCircuit.png "A resistor-capacitor circuit")
#
# Consider we are interested in the output voltage across the capacitor $C$ as $y(t)$. The current $i(t)$ is given by:
#
# $$i(t) = \frac{v_{in}(t)- y(t)}{R} $$
#
# The current across capacitor $C$ is given by:
#
# $$ i(t) = C \frac{dy}{dt} $$
#
# Combining those two equations and annotating $ \frac{dy}{dt} $ as $ \dot y$ we can finally write:
#
# $$ RC \dot y + y = v_{in} $$
#
# Let's simulate such a system subject to different input voltages $v_{in}(t)$.

# %% [markdown]
# # Response to a single step functions

# %%
def UnitStep(t):
    return 1

def OutputVoltage(y, t, f, a):
    R = 10e3              # 10k ohm
    C = 100e-6            # 100 u Farad
    
    v = a*f(t)     # the input voltage
    
    yp = (1.0/(R*C))*(v-y)
    return yp

timestep = 0.001
tend = 7

t = np.arange(0.0, tend, timestep)                 # interval of time of interest   
v0 = 0.2                                            # Initial voltage value on the capacitor

a1, a2 = 1, 3.3                                             # amplitude of the input voltage

v1 = a1*np.ones(t.size)                             # a unit step to help when plotting
y1 = odeint(OutputVoltage, v0, t, args=(UnitStep,a1))

v2 = a2*np.ones(t.size)                             # 3.3 V step to help when plotting
y2 = odeint(OutputVoltage, v0, t, args=(UnitStep,a2))

# %%
p = figure(plot_width=600, plot_height=400, title="RC response to step functions")

# response to unit step
p.line(t,v1, line_color = 'green')
p.line(t, y1[:,0], line_color = 'blue')

# response to 3.3 V
p.line(t,v2, line_color = 'green')
p.line(t, y2[:,0], line_color = 'blue')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d222dba6-3c03-4b4e-acad-e6ab60e9c1c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d222dba6-3c03-4b4e-acad-e6ab60e9c1c0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d222dba6-3c03-4b4e-acad-e6ab60e9c1c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd222dba6-3c03-4b4e-acad-e6ab60e9c1c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f9708c1-64e4-4c35-ad3e-484467cd1f5c":{"roots":{"references":[{"attributes":{"formatter":{"id":"79135089-bc17-4359-bea4-aaa4c81ef8ea","type":"BasicTickFormatter"},"plot":{"id":"5ec7395c-8155-4fa6-ac38-f067f318809b","subtype":"Figure","type":"Plot"},"ticker":{"id":"95103259-d286-4a0c-94f5-4e4f5dcc45f5","type":"BasicTicker"}},"id":"71ecfcd9-0952-4961-b356-148e5ea1633c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[7000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[7000]}}},"id":"85f0d3e8-a790-482f-873f-582584104a82","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"260a7465-13fa-4d50-8329-9efd14db0977","type":"BoxAnnotation"},"plot":{"id":"5ec7395c-8155-4fa6-ac38-f067f318809b","subtype":"Figure","type":"Plot"}},"id":"d62a063d-c567-42ac-baa8-4b37740244cd","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f25f4e1c-9161-4c57-8875-8fe07199b3c5","type":"Line"},{"attributes":{},"id":"79135089-bc17-4359-bea4-aaa4c81ef8ea","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[7000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[7000]}}},"id":"0eca65ee-76ed-411e-b151-d21977c931c6","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"RC response to step functions"},"id":"ba8a8fd1-7d3c-419d-93e9-52e322c80c17","type":"Title"},{"attributes":{"plot":{"id":"5ec7395c-8155-4fa6-ac38-f067f318809b","subtype":"Figure","type":"Plot"}},"id":"5457f039-4519-44ba-abda-84c4f14e8eab","type":"SaveTool"},{"attributes":{"data_source":{"id":"0eca65ee-76ed-411e-b151-d21977c931c6","type":"ColumnDataSource"},"glyph":{"id":"76122f7c-276c-4aa8-9860-d97186f7a56b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c97a792e-e04c-41aa-8c10-1e58c975a6b8","type":"Line"},"selection_glyph":null},"id":"8f8494bd-ce96-4a31-b74b-a88e889f8bd8","type":"GlyphRenderer"},{"attributes":{},"id":"95103259-d286-4a0c-94f5-4e4f5dcc45f5","type":"BasicTicker"},{"attributes":{"below":[{"id":"47f760c6-b549-4dc1-a2ed-d2cde7ac77ed","type":"LinearAxis"}],"left":[{"id":"71ecfcd9-0952-4961-b356-148e5ea1633c","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"47f760c6-b549-4dc1-a2ed-d2cde7ac77ed","type":"LinearAxis"},{"id":"763c19b6-bb93-4a44-b9ad-62444b56382b","type":"Grid"},{"id":"71ecfcd9-0952-4961-b356-148e5ea1633c","type":"LinearAxis"},{"id":"2d9542cb-cac0-435d-8487-7a58cf52fd4a","type":"Grid"},{"id":"260a7465-13fa-4d50-8329-9efd14db0977","type":"BoxAnnotation"},{"id":"7212ed89-4007-4b10-ab6b-e18ab170dfbf","type":"GlyphRenderer"},{"id":"8f8494bd-ce96-4a31-b74b-a88e889f8bd8","type":"GlyphRenderer"},{"id":"e8998aed-d408-4ce5-9384-d753c3c99389","type":"GlyphRenderer"},{"id":"8552d397-9b6a-486b-9512-98e55cabb207","type":"GlyphRenderer"}],"title":{"id":"ba8a8fd1-7d3c-419d-93e9-52e322c80c17","type":"Title"},"tool_events":{"id":"4f89248b-5319-40c3-a99f-dc478e2642c4","type":"ToolEvents"},"toolbar":{"id":"d812340e-779c-479a-963c-4eaae7c46a71","type":"Toolbar"},"x_range":{"id":"0a22b139-a33a-48d7-97cd-6809e0cab8f6","type":"DataRange1d"},"y_range":{"id":"0815445f-7fd0-4544-9ed4-971b0af92f99","type":"DataRange1d"}},"id":"5ec7395c-8155-4fa6-ac38-f067f318809b","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"96cab380-077f-4ce6-aea1-73f43bbf9e0e","type":"PanTool"},{"id":"f1899f82-a3c2-4895-b967-24e7c1e8a588","type":"WheelZoomTool"},{"id":"d62a063d-c567-42ac-baa8-4b37740244cd","type":"BoxZoomTool"},{"id":"5457f039-4519-44ba-abda-84c4f14e8eab","type":"SaveTool"},{"id":"50e57542-5b2d-42af-a030-55f6f3c89761","type":"ResetTool"},{"id":"2be743cf-54dc-4783-a06f-2a76d2d0dbef","type":"HelpTool"}]},"id":"d812340e-779c-479a-963c-4eaae7c46a71","type":"Toolbar"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x ...

# %% [markdown]
# ### Note that we can see the property of *homogeneity*

# %% [markdown]
# # Response to sine waves

# %%
def SineInput(t):
    return np.sin(t)

t = np.arange(0.0, 2*tend, timestep)                 # interval of time of interest   

v0 = 0
a1 = 1
a2 = 0.5

v1 = a1*np.sin(t)                             # sine wave of amplitude 1 to help when plotting
y1 = odeint(OutputVoltage, v0, t, args=(SineInput,a1))


v2 = a2*np.sin(t)                             # sine wave of amplitude 0.5 to help when plotting
y2 = odeint(OutputVoltage, v0, t, args=(SineInput,a2))

p = figure(plot_width=600, plot_height=400, title="RC response to sine functions")

# response to as sine wave of amplitude 1
p.line(t,v1, line_color = 'green')
p.line(t, y1[:,0], line_color = 'green', line_dash='dotted', line_width=3)

# response to as sine wave of amplitude 0.5
p.line(t,v2, line_color = 'blue')
p.line(t, y2[:,0], line_color = 'blue', line_dash='dotted', line_width=3)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ba2d81fb-a8b0-4a45-aa48-e3b4b43739c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ba2d81fb-a8b0-4a45-aa48-e3b4b43739c0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba2d81fb-a8b0-4a45-aa48-e3b4b43739c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba2d81fb-a8b0-4a45-aa48-e3b4b43739c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2aad3a26-5b22-4bd5-8fc5-6150c337a482":{"roots":{"references":[{"attributes":{"line_color":{"value":"green"},"line_dash":[2,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"70c133fd-5d9f-457a-ae32-1e4bab7d5a92","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"5bd2cd4b-6d7d-46a7-8d94-560b7b20d300","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8b2b49e8-315f-4ff4-a7af-74c1db413f07","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"5ac32c9c-eb4c-4175-a432-7de09331483d","type":"BasicTickFormatter"},"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"},"ticker":{"id":"15b6f2c9-c7c5-45d0-9829-a7ec98f7bb7d","type":"BasicTicker"}},"id":"5565bd86-ef28-482f-aef9-2164c16f3a30","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"033811de-83d5-43b5-a5c2-b97a0b61f0f1","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"95652167-f501-4457-8760-e6bd88cdcf00","type":"DataRange1d"},{"attributes":{"line_color":{"value":"blue"},"line_dash":[2,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"1bd145cc-009b-4e33-bc54-435320b9a41a","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"dea4d5e2-557c-4655-8e52-e9106266048e","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"},"ticker":{"id":"5307f689-a6ad-4770-8608-eecee07ee134","type":"BasicTicker"}},"id":"b38db7c0-1455-4f40-a54f-6921af6e1099","type":"Grid"},{"attributes":{"data_source":{"id":"5bd2cd4b-6d7d-46a7-8d94-560b7b20d300","type":"ColumnDataSource"},"glyph":{"id":"8bde8a3a-ca7d-4ea6-bcbc-cc4745edc2b9","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"904b7676-64dc-4918-98e3-b49ffd8ae690","type":"Line"},"selection_glyph":null},"id":"4efab8c9-774f-4414-9805-eb4ce75b63d3","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"904b7676-64dc-4918-98e3-b49ffd8ae690","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76f691d5-9a90-4de2-93e3-1ea3a91aa038","type":"Line"},{"attributes":{"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"}},"id":"acbd4a58-b1bd-4daf-895a-711bbab45c1c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"}},"id":"dacdaccf-88e6-4978-8fb1-47189235584e","type":"ResetTool"},{"attributes":{"formatter":{"id":"ef0ff63c-a780-42cb-b03c-06d0a6437581","type":"BasicTickFormatter"},"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"},"ticker":{"id":"5307f689-a6ad-4770-8608-eecee07ee134","type":"BasicTicker"}},"id":"0d1abd80-458c-450b-b066-89bea8288d60","type":"LinearAxis"},{"attributes":{"overlay":{"id":"8b2b49e8-315f-4ff4-a7af-74c1db413f07","type":"BoxAnnotation"},"plot":{"id":"032c1ed5-bf0f-4820-a994-c3f2b9a54c85","subtype":"Figure","type":"Plot"}},"id":"45381089-4dbf-4858-8db1-340324390be8","type":"BoxZoomTool"},{"attributes":{},"id":"5307f689-a6ad-4770-8608-eecee07ee134","type":"BasicTicker"},{"attributes":{"active_drag":"auto" ...

# %% [markdown]
# # Response to exponential

# %%
def ExpInput(t):
    return np.exp(-t)

t = np.arange(0.0, 2*tend, timestep)                 # interval of time of interest   

v0 = 0
a1 = 2

v1 = a1*np.exp(-t)                                     # exponential wave of amplitude 2 to help when plotting
y1 = odeint(OutputVoltage, v0, t, args=(ExpInput,a1))

p = figure(plot_width=600, plot_height=400, title="RC response to an exponential function")

# response to as sine wave of amplitude 1
p.line(t,v1, line_color = 'blue')
p.line(t, y1[:,0], line_color = 'blue', line_dash='dotted', line_width=3)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="91d06773-2ea0-42b7-ab07-122d0e504e55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("91d06773-2ea0-42b7-ab07-122d0e504e55").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("91d06773-2ea0-42b7-ab07-122d0e504e55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '91d06773-2ea0-42b7-ab07-122d0e504e55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7601177-799c-45e1-bae2-92f07d3177bd":{"roots":{"references":[{"attributes":{"overlay":{"id":"40341753-ba01-4747-970c-eae676139be8","type":"BoxAnnotation"},"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"}},"id":"a79b0f1c-8ec6-4693-be63-4e09676fca7b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"}},"id":"22c0b640-4b79-4d95-8495-97344a088386","type":"PanTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"6984124d-c9de-4326-8dd4-172b2797f451","type":"ColumnDataSource"},{"attributes":{},"id":"5a70c8a2-bc72-4f40-9dfa-ab885a4b1ba5","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"48b43e2a-a978-4f86-976b-3914f10ff894","type":"BasicTickFormatter"},"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"},"ticker":{"id":"89f922ef-0d8e-4f98-9562-1e0c85d6de62","type":"BasicTicker"}},"id":"5d960a03-e4b9-4bad-9c1b-d556661bd73e","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"2288156e-3bf0-456c-b4ac-d89bc41cfa89","type":"Line"},{"attributes":{"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"}},"id":"78089258-d968-407b-b0ae-e34ea3511b47","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"}},"id":"e7e0c2e9-b036-4e2f-bf46-c4af0f5dc3fa","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"40341753-ba01-4747-970c-eae676139be8","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"blue"},"line_dash":[2,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"9cc9f8ca-77b4-47f1-8f14-33418fb504d9","type":"Line"},{"attributes":{},"id":"c6b0f7e3-9c88-44bb-832f-385e6d23f754","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6984124d-c9de-4326-8dd4-172b2797f451","type":"ColumnDataSource"},"glyph":{"id":"001f7f0d-88cd-4f91-b8c1-4c524f970681","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"522c929b-1b69-4b56-8a69-5d7acb898834","type":"Line"},"selection_glyph":null},"id":"427ff08d-48a8-42de-9157-ec6cb3662888","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"de040776-3ee4-4d7e-9dbd-603b7ca906d1","type":"ColumnDataSource"},"glyph":{"id":"9cc9f8ca-77b4-47f1-8f14-33418fb504d9","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2288156e-3bf0-456c-b4ac-d89bc41cfa89","type":"Line"},"selection_glyph":null},"id":"a1ba5a43-5ef6-4159-87ec-a725844df992","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"RC response to an exponential function"},"id":"491d2e4d-08a6-4b90-911c-2764d45eb412","type":"Title"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"001f7f0d-88cd-4f91-b8c1-4c524f970681","type":"Line"},{"attributes":{"plot":{"id":"bb5a885b-7934-472f-bddb-900fc945b614","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6b0f7e3-9c88-44bb-832f-385e6d23f754","type":"BasicTicker"}},"id":"3a3b73e3-827b-4f05-9cff-101e8b64ecdd","type":"Grid"},{"attributes":{},"id":"89f922ef-0d8e-4f98-9562-1e0c85d6de62","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ccbb1a62-b609-4669-ad96-8c47b524c474","type":"DataRange1d"},{"attributes":{"below":[{"id":"64219a5f-5607-452c-a346-d108fc11cc21","type":"LinearAxis"}],"left":[{"id":"5d960a03-e4b9-4bad-9c1b-d556661bd73e","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id ...

# %% [markdown]
# # Response to an input of two waveforms

# %%
def OutputVoltage2(y, t, f, g, a1, a2):
    R = 10e3              # 10k ohm
    C = 100e-6            # 100 u Farad
    
    v1 = a1*f(t) 
    v2 = a2*g(t)     
    v = v1 + v2           # the sum of 2 input voltages
    
    yp = (1.0/(R*C))*(v-y)
    return yp

def ExpSineInput(t):
    x1 = np.exp
    return np.exp(-t)


# Exponential function with amplitude 2
v0 = 0
a1 = 4

v1 = a1*np.exp(-t)                                     # exponential wave of amplitude 2 to help when plotting
y1 = odeint(OutputVoltage, v0, t, args=(ExpInput,a1))

# Sine wave with amplitude 0.5
a2 = 0.5

v2 = a2*np.sin(t)                             # sine wave of amplitude 1 to help when plotting
y2 = odeint(OutputVoltage, v0, t, args=(SineInput,a2))

vc = a1*np.exp(-t) + a2*np.sin(t)
yc = odeint(OutputVoltage2, v0, t, args=(ExpInput,SineInput, a1, a2))


p = figure(plot_width=600, plot_height=400)

# response to as sine wave of amplitude 1
p.line(t,v1+v2, line_color = 'blue')
p.line(t, y1[:,0]+y2[:,0], line_color = 'blue', line_dash='dotted', line_width=3)

p.line(t,vc, line_color = 'red', line_dash='dashdot', line_width=1)
p.line(t, yc[:,0], line_color = 'red', line_dash='dashdot', line_width=1)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="83914b22-bef2-4526-8438-558e83b50a5e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("83914b22-bef2-4526-8438-558e83b50a5e").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83914b22-bef2-4526-8438-558e83b50a5e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83914b22-bef2-4526-8438-558e83b50a5e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf5ecb66-2b74-44ed-a30d-f3d44a7a60b8":{"roots":{"references":[{"attributes":{"line_color":{"value":"blue"},"line_dash":[2,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e572db33-ff89-4e98-b372-5238d468910c","type":"Line"},{"attributes":{},"id":"53ae7d4d-c0cf-4425-860d-7b2ce20a96f0","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"179105c5-3ad0-41c6-b498-0784e9ea2b3c","type":"LinearAxis"}],"left":[{"id":"1b04192c-07cc-4967-b451-057e6b634e5a","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"179105c5-3ad0-41c6-b498-0784e9ea2b3c","type":"LinearAxis"},{"id":"bd1513dd-3dab-47ef-ab8e-57b603591cca","type":"Grid"},{"id":"1b04192c-07cc-4967-b451-057e6b634e5a","type":"LinearAxis"},{"id":"ef3f76a4-e242-4d5f-b803-c3c27dbf8582","type":"Grid"},{"id":"b9c8a39d-5281-4b11-b6b4-7e37ff9a2d90","type":"BoxAnnotation"},{"id":"efda6d2e-c250-44ea-855d-f9347a413dc8","type":"GlyphRenderer"},{"id":"f2ad6060-277e-4e85-9a34-30129dcf8956","type":"GlyphRenderer"},{"id":"8f5d5112-454e-4431-a9ef-86bb30116af9","type":"GlyphRenderer"},{"id":"4ade65ab-2b8d-465e-9672-6215c5f9e38c","type":"GlyphRenderer"}],"title":{"id":"db0b940a-0c9f-42a7-a002-cffb6ec50587","type":"Title"},"tool_events":{"id":"9aa1b250-4dcf-4926-8a5e-fa4f58a8f638","type":"ToolEvents"},"toolbar":{"id":"a4a24d72-0ac0-4ba1-a2d7-63566ca8119d","type":"Toolbar"},"x_range":{"id":"b09fc684-81fa-4561-916c-877eb4fc1cf6","type":"DataRange1d"},"y_range":{"id":"4ec934b0-59e9-49b2-a9c3-fdbe2b87d966","type":"DataRange1d"}},"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"4ec934b0-59e9-49b2-a9c3-fdbe2b87d966","type":"DataRange1d"},{"attributes":{"overlay":{"id":"b9c8a39d-5281-4b11-b6b4-7e37ff9a2d90","type":"BoxAnnotation"},"plot":{"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"}},"id":"68d8e838-fd7b-4ec5-bcfa-9512143e2fcc","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"}},"id":"91052a78-33d8-484c-be3b-8d3cac148a0a","type":"HelpTool"},{"attributes":{"formatter":{"id":"bcbf2c37-301f-48ac-9ce3-c16e87848e96","type":"BasicTickFormatter"},"plot":{"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c0a7932-bbbc-42e2-842d-d695378166c6","type":"BasicTicker"}},"id":"1b04192c-07cc-4967-b451-057e6b634e5a","type":"LinearAxis"},{"attributes":{},"id":"9aa1b250-4dcf-4926-8a5e-fa4f58a8f638","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"db0b940a-0c9f-42a7-a002-cffb6ec50587","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"06e4bd92-7026-4a8c-8c50-7c59db1bf01e","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"53ae7d4d-c0cf-4425-860d-7b2ce20a96f0","type":"BasicTickFormatter"},"plot":{"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ff9841d-fac7-461c-a98e-d72b0db0e447","type":"BasicTicker"}},"id":"179105c5-3ad0-41c6-b498-0784e9ea2b3c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[14000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[14000]}}},"id":"3ce0891b-21a0-48be-80cc-f17c9ffbc871","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f3d5733-2aa5-4faa-9e88-821f1fdd1f14","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6,4,2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"e1c0f9ba-dedd-45b2-928f-91da8f5b716d","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"9ec63289-a3aa-49da-bdf3-e09007522b1f","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c0a7932-bbbc-42e2-842d-d695378166c6","type":"BasicTicker ...

# %% [markdown]
# ### This is the property of *superposition* for linear systems

# %% [markdown]
# # An example of a non linear system
# The last slide on Lecture 2 had the equation:
#
# $$ T = MgL \sin(\theta) $$
#
# Note: $\theta$ is the independent variable, so this system does not depend on time $t$ but on angle $\theta$.

# %%
M = 0.5            # half a kilogram
g = 9.81           # gravity value in MKS
L = 0.3            # 30 cm of arm length

theta = np.arange(0, 3*np.pi, 0.01)        # the range of interest for theta

ftheta = 0.5*np.sin(theta) + 2*np.cos(theta) #to try the principle of superposition
T = M*g*L*np.sin(ftheta)

p = figure(plot_width=600, plot_height=400)

# the input function in blue
p.line(theta,ftheta, line_color = 'blue')
# the torque output T
p.line(theta,T, line_color = 'red')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3295c5a1-846d-4bf1-a473-15a950a87e17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3295c5a1-846d-4bf1-a473-15a950a87e17").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3295c5a1-846d-4bf1-a473-15a950a87e17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3295c5a1-846d-4bf1-a473-15a950a87e17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d53a5e8e-445c-4888-8555-b5899e034953":{"roots":{"references":[{"attributes":{"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"}},"id":"b63b7705-5658-4fd4-bcd8-4ad89d2fc737","type":"ResetTool"},{"attributes":{"formatter":{"id":"f65a8309-daa4-4d49-8ba5-a23122e298a7","type":"BasicTickFormatter"},"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"},"ticker":{"id":"e76a2f37-786c-426c-9ed6-4eafd6dc0cfc","type":"BasicTicker"}},"id":"3289d6d0-fd65-4c25-93ca-535881491399","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"763a5bd6-4708-409e-bc02-52470b0b590d","type":"PanTool"},{"id":"658667ed-7930-49a4-8fd3-3f44652c108e","type":"WheelZoomTool"},{"id":"ab7274f7-f632-4afd-8b87-1168f9a7d2d7","type":"BoxZoomTool"},{"id":"47bfb19b-32a1-498c-af7e-5220eafc8eb0","type":"SaveTool"},{"id":"b63b7705-5658-4fd4-bcd8-4ad89d2fc737","type":"ResetTool"},{"id":"44352359-7340-4f9e-9717-3ea04b73b6c9","type":"HelpTool"}]},"id":"648145bf-f351-4954-84d9-64c88e667afb","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"671af1fd-d57b-47ea-905f-bdb2553dddc0","type":"Line"},{"attributes":{"data_source":{"id":"1f6faed9-afe3-4704-985a-28bfca7d85e1","type":"ColumnDataSource"},"glyph":{"id":"432d4b40-4897-4024-90d9-647aa9ae786f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"779a8cd3-265c-437d-ac7a-82a9f75f56ef","type":"Line"},"selection_glyph":null},"id":"e5644f3e-c296-4132-8194-919f38fe7017","type":"GlyphRenderer"},{"attributes":{},"id":"9d6a120c-bf46-44cb-8c89-cc5b50cee02d","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"779a8cd3-265c-437d-ac7a-82a9f75f56ef","type":"Line"},{"attributes":{"data_source":{"id":"04db9bc9-5c97-45b5-8747-d9d0d66d0a71","type":"ColumnDataSource"},"glyph":{"id":"d482c397-e1f4-4964-80a4-c47d405ca085","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"671af1fd-d57b-47ea-905f-bdb2553dddc0","type":"Line"},"selection_glyph":null},"id":"a7664ead-68e1-493b-9e2c-a0acc8d44fe9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"},"ticker":{"id":"fea3668c-9f89-410b-8106-1a228622367e","type":"BasicTicker"}},"id":"992ac0aa-43eb-4baa-8379-447ce566ce5c","type":"Grid"},{"attributes":{"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"}},"id":"658667ed-7930-49a4-8fd3-3f44652c108e","type":"WheelZoomTool"},{"attributes":{},"id":"fea3668c-9f89-410b-8106-1a228622367e","type":"BasicTicker"},{"attributes":{},"id":"2d0390b4-dee5-42fa-a1b4-adba78e5014e","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d482c397-e1f4-4964-80a4-c47d405ca085","type":"Line"},{"attributes":{},"id":"e76a2f37-786c-426c-9ed6-4eafd6dc0cfc","type":"BasicTicker"},{"attributes":{"overlay":{"id":"0b0adb14-3e87-4ece-a8f5-aa640facab5f","type":"BoxAnnotation"},"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"}},"id":"ab7274f7-f632-4afd-8b87-1168f9a7d2d7","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"21086305-2eff-4850-aee5-0b62e4bed209","subtype":"Figure","type":"Plot"},"ticker":{"id":"e76a2f37-786c-426c-9ed6-4eafd6dc0cfc","type":"BasicTicker"}},"id":"4247c5dd-b0f4-4d88-9eb1-5b46abd1742f","type":"Grid"},{"attributes":{"callback":null},"id":"f198d17d-dc72-4d5e-b449-d8b2730d0891","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"eeaf6969-c45e-4967-9a78-8b8557b19fab","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[943]},"y":{"__ndarray__":"...","dtype":"float64","shape":[943]}}},"id":"1f6faed9-afe3-4704-985a-28bfca7d85e1" ...

# %% [markdown]
# ### Note this response is not linear, so the function $ y = sin(x) $ is not linear.
