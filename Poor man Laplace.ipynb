# %%
import numpy as np
#from numpy import trapz

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="da778e0c-7873-4606-8f70-09966c7f4276">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Let's try to compute the Laplace transform in a very naive way
#
# $$G(s) = \int_{0}^{\infty} g(t)e^{-st} dt $$

# %%
s = 3                              # a constant 
deltat = 0.001                     # time incremenet 
t = np.arange(0, 10, deltat)       # time vector, not to infinity

# %% [markdown]
# ## with a unit step function

# %%
g = np.ones(t.size)                # a unit step acting as g(t)
ge = np.exp(-s*t)*g                # the integrand

# %%
p = figure(plot_width=800, plot_height=300, title="A unit step times and exponential instance")

p.line(t,ge, line_color = 'blue')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01acfa27-f8dc-41f1-9885-8a170ce9a160"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("01acfa27-f8dc-41f1-9885-8a170ce9a160").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01acfa27-f8dc-41f1-9885-8a170ce9a160");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01acfa27-f8dc-41f1-9885-8a170ce9a160' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"161d63b7-e565-4aa1-a4b9-ba07d425d87a":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f1ccec7-ea95-4ea3-8e9f-2c1af76ecdea","type":"Line"},{"attributes":{"plot":null,"text":"A unit step times and exponential instance"},"id":"aed311da-a977-4b7b-b9fb-f7128251a80d","type":"Title"},{"attributes":{"plot":{"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"}},"id":"b3884759-567b-4fa7-bc31-78757ba533db","type":"HelpTool"},{"attributes":{"plot":{"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"}},"id":"37488c71-40f8-40a8-bbab-56e1ae0ef5f1","type":"PanTool"},{"attributes":{},"id":"84f006a3-fe7b-4611-ad4e-b85ef8a2c765","type":"ToolEvents"},{"attributes":{"overlay":{"id":"a847f688-ab80-4ada-9d6d-b8492a463468","type":"BoxAnnotation"},"plot":{"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"}},"id":"6cf30b78-b386-4657-b701-084c21b045b6","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"24e8b06c-0984-440d-8b21-1de570393bba","type":"ColumnDataSource"},"glyph":{"id":"ae9896bb-ed8d-4b07-811c-833ca530112c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"8f1ccec7-ea95-4ea3-8e9f-2c1af76ecdea","type":"Line"},"selection_glyph":null},"id":"0a750b5a-0f47-40c3-937b-d18cbf0d980a","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"37488c71-40f8-40a8-bbab-56e1ae0ef5f1","type":"PanTool"},{"id":"5a2ca6f6-d7f0-4b72-bac0-a6770b69130f","type":"WheelZoomTool"},{"id":"6cf30b78-b386-4657-b701-084c21b045b6","type":"BoxZoomTool"},{"id":"5ee05528-0db0-492f-9d3e-effdfb3b5608","type":"SaveTool"},{"id":"76cc8f6d-8382-4e1b-9188-313735991ac2","type":"ResetTool"},{"id":"b3884759-567b-4fa7-bc31-78757ba533db","type":"HelpTool"}]},"id":"e626fefc-6d7d-45cb-8868-f9e1532bb662","type":"Toolbar"},{"attributes":{"formatter":{"id":"5f6c719f-409c-49e3-89ee-4af4b6db9901","type":"BasicTickFormatter"},"plot":{"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"74ac3691-dcfd-44e3-bc53-5c5c5120eee0","type":"BasicTicker"}},"id":"122beb4a-0ac5-4099-bd14-43c113065cff","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"},"ticker":{"id":"74ac3691-dcfd-44e3-bc53-5c5c5120eee0","type":"BasicTicker"}},"id":"0e99b29c-26f7-40c4-8ebb-557fcec988b4","type":"Grid"},{"attributes":{"callback":null},"id":"6f385252-6ac2-46fe-abfa-1a69536939e9","type":"DataRange1d"},{"attributes":{"below":[{"id":"31b6974f-59e0-41ab-a188-e3ae39d69f19","type":"LinearAxis"}],"left":[{"id":"122beb4a-0ac5-4099-bd14-43c113065cff","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"31b6974f-59e0-41ab-a188-e3ae39d69f19","type":"LinearAxis"},{"id":"e4fd0a96-effd-4f95-9262-c22215ef380a","type":"Grid"},{"id":"122beb4a-0ac5-4099-bd14-43c113065cff","type":"LinearAxis"},{"id":"0e99b29c-26f7-40c4-8ebb-557fcec988b4","type":"Grid"},{"id":"a847f688-ab80-4ada-9d6d-b8492a463468","type":"BoxAnnotation"},{"id":"0a750b5a-0f47-40c3-937b-d18cbf0d980a","type":"GlyphRenderer"}],"title":{"id":"aed311da-a977-4b7b-b9fb-f7128251a80d","type":"Title"},"tool_events":{"id":"84f006a3-fe7b-4611-ad4e-b85ef8a2c765","type":"ToolEvents"},"toolbar":{"id":"e626fefc-6d7d-45cb-8868-f9e1532bb662","type":"Toolbar"},"x_range":{"id":"6f385252-6ac2-46fe-abfa-1a69536939e9","type":"DataRange1d"},"y_range":{"id":"9aa69905-6e21-4e47-beaf-5b707f0d75db","type":"DataRange1d"}},"id":"79144047-4682-4264-ac36-d261aa25afb0","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen" ...

# %% [markdown]
# Let's try to calculate this area

# %%
gs = np.exp(-s*t)*g*deltat
myarea = gs.sum()

print("The area under the curve in a naive way is: %f" % myarea)
# Out:
# The area under the curve in a naive way is: 0.333834

# %%
area = np.trapz(ge, dx = deltat)                       # proper way of comuting the integral 
print("The area under the curve in a proper way is: %f" % area)
# Out:
# The area under the curve in a proper way is: 0.333334

# %% [markdown]
# ## with an exponential function

# %%
a = 2
g = np.exp(-a*t)                       # an exponential acting as g(t)
ge = np.exp(-s*t)*g                    # the integrand 

gs = ge*deltat
myarea = gs.sum()
print("The area under the curve in a naive way is: %f" % myarea)

area = np.trapz(ge, dx = deltat)                       # proper way of comuting the integral 
print("The area under the curve in a proper way is: %f" % area)
# Out:
# The area under the curve in a naive way is: 0.200500
# The area under the curve in a proper way is: 0.200000

# %%
p = figure(plot_width=800, plot_height=300, title="The functions to calculate the Laplace of an exponential")

p.line(t,np.exp(-t), line_color = 'green', line_dash='dotted')
p.line(t,g, line_color = 'blue', line_dash='dotted')
p.line(t,ge, line_color = 'red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7a7d0606-425f-4ab0-ba61-dde565c47e94"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7a7d0606-425f-4ab0-ba61-dde565c47e94").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a7d0606-425f-4ab0-ba61-dde565c47e94");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a7d0606-425f-4ab0-ba61-dde565c47e94' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3fdda6c-b74c-4a22-827f-a898db9dc3c5":{"roots":{"references":[{"attributes":{},"id":"dfc68156-e16a-4067-97e6-045206dfcb5f","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"green"},"line_dash":[2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"2095839b-3b8c-4de4-b713-12d76ea10de0","type":"Line"},{"attributes":{"data_source":{"id":"e962df0d-d11c-4212-b88f-75184b918e48","type":"ColumnDataSource"},"glyph":{"id":"5b19c712-6471-426a-859e-d669fe5a143b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"bf758dc9-831d-4cba-aa2c-54a8da703a97","type":"Line"},"selection_glyph":null},"id":"28a1f6d9-f14d-45e8-9632-0264a18c8743","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"},"ticker":{"id":"771cdb80-343d-438c-ac10-f6fdfcfda662","type":"BasicTicker"}},"id":"7d9ea671-721f-4b57-a7a8-62fedaffb55d","type":"Grid"},{"attributes":{"below":[{"id":"c4e8f0ef-517b-44b1-8c23-33e341629e48","type":"LinearAxis"}],"left":[{"id":"2d8be519-c7b6-4d26-a2b0-b36645466711","type":"LinearAxis"}],"plot_height":300,"plot_width":800,"renderers":[{"id":"c4e8f0ef-517b-44b1-8c23-33e341629e48","type":"LinearAxis"},{"id":"7d9ea671-721f-4b57-a7a8-62fedaffb55d","type":"Grid"},{"id":"2d8be519-c7b6-4d26-a2b0-b36645466711","type":"LinearAxis"},{"id":"7c162ca3-54df-4627-a57e-b00f7541722a","type":"Grid"},{"id":"11e5af28-25ba-42f3-a225-29fc3c57d2d5","type":"BoxAnnotation"},{"id":"5e2387a5-ffc7-4e31-80d2-71b1cd2741de","type":"GlyphRenderer"},{"id":"a4d95578-e740-420f-8979-2e5a3fe96e21","type":"GlyphRenderer"},{"id":"28a1f6d9-f14d-45e8-9632-0264a18c8743","type":"GlyphRenderer"}],"title":{"id":"12f113b7-61a0-4e44-8574-661ad4edb196","type":"Title"},"tool_events":{"id":"37c685bc-51c3-4f04-959f-cbebb82a4ab3","type":"ToolEvents"},"toolbar":{"id":"5ea9409a-7fe5-4c2f-859e-639f7a08e953","type":"Toolbar"},"x_range":{"id":"bd8dd5c2-42d3-411a-9c68-24f35dd62816","type":"DataRange1d"},"y_range":{"id":"9b459be0-963d-4ae9-ba07-8d45897847e3","type":"DataRange1d"}},"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"11e5af28-25ba-42f3-a225-29fc3c57d2d5","type":"BoxAnnotation"},"plot":{"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"}},"id":"808c97e0-60c1-4db1-9080-e44c15adec38","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"}},"id":"889cdaad-063d-4b0a-ac49-7a47b646644b","type":"SaveTool"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b19c712-6471-426a-859e-d669fe5a143b","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"},"ticker":{"id":"6446d2d5-8a1b-4c97-82df-b69a692d9209","type":"BasicTicker"}},"id":"7c162ca3-54df-4627-a57e-b00f7541722a","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"458e43d3-bde6-44bc-888c-50aabbba9570","type":"Line"},{"attributes":{"plot":{"id":"8e51f581-327e-404e-9b36-a039f219c97d","subtype":"Figure","type":"Plot"}},"id":"659b6a14-78e0-4149-a390-28c1f9446dad","type":"HelpTool"},{"attributes":{"data_source":{"id":"816aa7c5-e37f-4764-b6a5-0215e980c042","type":"ColumnDataSource"},"glyph":{"id":"df213019-18b9-4c1c-972d-49ee1cc90283","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"fa04af0a-5cad-4357-aa47-4218d59bb2da","type":"Line"},"selection_glyph":null},"id":"a4d95578-e740-420f-8979-2e5a3fe96e21","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b55f89ed-a398-401e-98ce-6fce47721500","type":"PanTool"},{"id":"5fa227e3-2201-4e23-9919-07985036430a","type":"WheelZoomTool"},{"id":"808c97e0-60c1-4db1-9080-e44c15adec38","type":"BoxZoomTool"},{"id":"889cdaad-063d-4b0a-ac49-7a47b646644b","type":"Save ...

# %% [markdown]
# ## with an impulse

# %%
g = np.zeros(t.size)
g[0] = 1/deltat                        # notice you need an area of 1 for the impulse function

ge = np.exp(-s*t)*g                    # the integrand 

gs = ge*deltat
myarea = gs.sum()
print("The area under the curve in a naive way is: %f" % myarea)
# Out:
# The area under the curve in a naive way is: 1.000000

# %%
p = figure(plot_width=800, plot_height=200, title="The functions to calculate the Laplace of an impulse")

p.line(t,ge, line_color = 'blue')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b1dc7780-d177-4f4c-a3d8-61ee6ac88def"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b1dc7780-d177-4f4c-a3d8-61ee6ac88def").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1dc7780-d177-4f4c-a3d8-61ee6ac88def");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1dc7780-d177-4f4c-a3d8-61ee6ac88def' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ce150b1-588a-4158-b24e-ef435e366bd8":{"roots":{"references":[{"attributes":{"formatter":{"id":"2e98a38c-d9e0-4c57-8aa1-83e7e63424ac","type":"BasicTickFormatter"},"plot":{"id":"4c54e674-7d30-4452-a2b6-dcd18717cefd","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb24c94a-6a74-41a5-bf96-b1996af4ef37","type":"BasicTicker"}},"id":"591f6651-89ad-4be1-a7eb-5c2cbc49eb61","type":"LinearAxis"},{"attributes":{"data_source":{"id":"94ce1e06-b9cd-41d2-9ee5-72150f54e7f7","type":"ColumnDataSource"},"glyph":{"id":"090d0d76-26ed-4794-a42a-9e0728ba6338","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dadc6792-2143-4454-a004-2ffabe80ac72","type":"Line"},"selection_glyph":null},"id":"a1bfb413-5392-4781-8edf-01744473ce5f","type":"GlyphRenderer"},{"attributes":{},"id":"2e98a38c-d9e0-4c57-8aa1-83e7e63424ac","type":"BasicTickFormatter"},{"attributes":{},"id":"7901c4f7-942f-4b2d-a608-d22acc45594c","type":"ToolEvents"},{"attributes":{"plot":{"id":"4c54e674-7d30-4452-a2b6-dcd18717cefd","subtype":"Figure","type":"Plot"}},"id":"72247869-ab4d-4744-a316-9a6e7505174c","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"34ab9276-64cd-4d8d-aebb-2b5250b13051","type":"PanTool"},{"id":"4add24b5-90d5-4274-a319-0109104a0aac","type":"WheelZoomTool"},{"id":"485053f4-6d09-44a2-ac50-0d22f466756c","type":"BoxZoomTool"},{"id":"6c588a16-21b1-4819-880d-dc2392a6a35f","type":"SaveTool"},{"id":"72247869-ab4d-4744-a316-9a6e7505174c","type":"ResetTool"},{"id":"00badf4b-4c5b-4162-af78-daf8f7abe629","type":"HelpTool"}]},"id":"fd978b03-907b-415f-bdbb-61011a401859","type":"Toolbar"},{"attributes":{"plot":{"id":"4c54e674-7d30-4452-a2b6-dcd18717cefd","subtype":"Figure","type":"Plot"}},"id":"00badf4b-4c5b-4162-af78-daf8f7abe629","type":"HelpTool"},{"attributes":{},"id":"a57976c0-c873-41c0-a325-05f93283dcc3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4c54e674-7d30-4452-a2b6-dcd18717cefd","subtype":"Figure","type":"Plot"}},"id":"4add24b5-90d5-4274-a319-0109104a0aac","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c1b64d63-95fd-4d6c-9425-0ff6ec7628a9","type":"BoxAnnotation"},{"attributes":{},"id":"cb24c94a-6a74-41a5-bf96-b1996af4ef37","type":"BasicTicker"},{"attributes":{"plot":{"id":"4c54e674-7d30-4452-a2b6-dcd18717cefd","subtype":"Figure","type":"Plot"}},"id":"34ab9276-64cd-4d8d-aebb-2b5250b13051","type":"PanTool"},{"attributes":{"plot":null,"text":"The functions to calculate the Laplace of an impulse"},"id":"0c3eff09-ba0c-43b7-8c1d-033abf82153c","type":"Title"},{"attributes":{"callback":null},"id":"c3ca841f-7b18-4c34-a128-6448c24aed11","type":"DataRange1d"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"090d0d76-26ed-4794-a42a-9e0728ba6338","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dadc6792-2143-4454-a004-2ffabe80ac72","type":"Line"},{"attributes":{"below":[{"id":"591f6651-89ad-4be1-a7eb-5c2cbc49eb61","type":"LinearAxis"}],"left":[{"id":"c5d386d6-1c6a-499f-afda-5d1f76dbf53d","type":"LinearAxis"}],"plot_height":200,"plot_width":800,"renderers":[{"id":"591f6651-89ad-4be1-a7eb-5c2cbc49eb61","type":"LinearAxis"},{"id":"1b25dda2-2473-4ecc-9a09-acb207d87d4d","type":"Grid"},{"id":"c5d386d6-1c6a-499f-afda-5d1f76dbf53d","type":"LinearAxis"},{"id":"2c792ab4-86c8-4f12-ba1f-1ca0f68f6c81","type":"Grid"},{"id":"c1b64d63-95fd-4d6c-9425-0ff6ec7628a9","type":"BoxAnnotation"},{"id":"a1bfb413-5392-4781-8edf-01744473ce5f","type":"GlyphRenderer"}],"title":{"id":"0c3eff09-ba0c-43b7-8c1d-033abf82153c","type":"Title"},"tool_events":{"id":"7901c4f7-942f-4b2d-a60 ...
